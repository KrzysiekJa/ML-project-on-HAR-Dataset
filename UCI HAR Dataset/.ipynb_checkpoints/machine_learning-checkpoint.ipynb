# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# importing files with allready preprocesed data
df_X_train = pd.read_csv('train/X_train.txt', header=None, delim_whitespace=True)
df_y_train = pd.read_csv('train/y_train.txt', header=None, delim_whitespace=True)
df_X_test  = pd.read_csv('test/X_test.txt', header=None, delim_whitespace=True)
df_y_test  = pd.read_csv('test/y_test.txt', header=None, delim_whitespace=True)

print(df_X_train.isnull().sum(), '\n', df_X_test.isnull().sum())
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 556    0
# 557    0
# 558    0
# 559    0
# 560    0
# Length: 561, dtype: int64 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 556    0
# 557    0
# 558    0
# 559    0
# 560    0
# Length: 561, dtype: int64

# %%
df_X_train.dropna().reset_index(drop=True)
df_X_test.dropna().reset_index(drop=True)
df_X_train.head(10)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# 5  0.277199 -0.010098 -0.105137 -0.997335 -0.990487 -0.995420 -0.997627
# 6  0.279454 -0.019641 -0.110022 -0.996921 -0.967186 -0.983118 -0.997003
# 7  0.277432 -0.030488 -0.125360 -0.996559 -0.966728 -0.981585 -0.996485
# 8  0.277293 -0.021751 -0.120751 -0.997328 -0.961245 -0.983672 -0.997596
# 9  0.280586 -0.009960 -0.106065 -0.994803 -0.972758 -0.986244 -0.995405
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.983185 -0.923527 -0.934724  ... -0.074323 -0.298676 -0.710304 -0.112754
# ...

# %%
print(df_X_train.shape, df_y_train.shape, df_X_test.shape, df_y_test.shape)
# Out:
# (7352, 561) (7352, 1) (2947, 561) (2947, 1)

# %%
X = pd.concat([df_X_train, df_X_test], ignore_index=True)
y = pd.concat([df_y_train, df_y_test], ignore_index=True)

del df_X_train, df_X_test, df_y_train, df_y_test

print(df_X_train.shape, df_y_train.shape, df_X_test.shape, df_y_test.shape, '\n', X.describe)
